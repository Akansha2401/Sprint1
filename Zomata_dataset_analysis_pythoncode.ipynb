# %% [markdown]
# # **Project Name: Zomato Dataset Analysis**
#
# **By,**
#
# **Akansha Kotian** and **Faisal Shaikh**

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# Analyze and clean the Zomato dataset, extract insights, and prepare the data for further analysis.

# %% [markdown]
# # **Objective**

# %% [markdown]
# 1. Clean and preprocess the Zomato dataset for analysis.
# 2. Perform exploratory data analysis to uncover trends and patterns.
# 3. Derive insights on restaurant ratings, cost, and customer preferences.
# 4. Visualize data to enhance understanding and support decision-making.

# %% [markdown]
# # *Understanding Variable*

# %%
# **- url:** URL of the restaurant's Zomato page
# **- address:** Address of the restaurant
# - name: Name of the restaurant
# - online_order: Whether the restaurant accepts online orders (Yes/No)
# - book_table: Whether the restaurant allows table bookings (Yes/No)
# - rate: Restaurant rating out of 5
# - votes: Number of votes the restaurant has received
# - phone: Contact number(s) of the restaurant
# - location: The location of the restaurant
# - rest_type: Type of restaurant (Casual Dining, Cafe, etc.)
# - dish_liked: Most liked dishes in the restaurant
# - cuisines: Cuisines offered by the restaurant
# - approx_cost(for two): Approximate cost for two people (in ₹)
# - reviews_list: List of reviews (if available)
# - menu_item: Menu items listed
# - listed_in(type): Whether the restaurant is listed for Buffet or Cafes
# - listed_in(city): City where the restaurant is listed

# %% [markdown]
# # *Dataset Link*
#  https://www.kaggle.com/datasets/himanshupoddar/zomato-bangalore-restaurants/data

# %% [markdown]
# # *Github Link*

# %% [markdown]
# https://github.com/Akansha2401/Sprint1

# %%
# Installing the packages
# !pip install panda
# !pip install matplotlib
# !pip install numpy
# !pip install seaborn
# !pip install sidetable
# !pip install pandas numpy seaborn matplotlib
# Out:
# ...
# [notice] A new release of pip is available: 23.0.1 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 23.0.1 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 23.0.1 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 23.0.1 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 23.0.1 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 23.0.1 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# **Insight:**
#
# Installing necessary libraries for data manipulation and visualization

# %% [markdown]
# # *Import necessary packages*

# %%
# Importing the necessary packages for data manipulation and visualization
import pandas as pd   # Data Manipulation
import matplotlib.pyplot as plt   # Data Visualization
import numpy as np   # Mathematical Calculation
import seaborn as sns   # Advanced Data Visualization based on matplotlib
import sidetable as stb   # Extends pandas with additional summary tables

# Set a light background manually
plt.rcParams.update({
    'axes.facecolor': 'white',    # Background color of the plot
    'axes.edgecolor': 'black',    # Color of the border lines
    'grid.color': 'lightgray',    # Gridline color
    'grid.linestyle': '-',        # Gridline style
    'grid.alpha': 0.7             # Gridline transparency
})

# %% [markdown]
# **Insight**
# Imported all necessary packages

# %% [markdown]
# # *Loading the files from the local system to the Notebook*

# %%
import pandas as pd

# Correctly specify the file path
file_path = r'C:\Users\akans\OneDrive\Documents\zomato.csv'

# Load the dataset
df = pd.read_csv(file_path)   # Function to read the CSV file from the file path
df
# Out:
#                                                      url  \
# 0      https://www.zomato.com/bangalore/jalsa-banasha...
# 1      https://www.zomato.com/bangalore/spice-elephan...
# 2      https://www.zomato.com/SanchurroBangalore?cont...
# 3      https://www.zomato.com/bangalore/addhuri-udupi...
# 4      https://www.zomato.com/bangalore/grand-village...
# ...                                                  ...
# 51712  https://www.zomato.com/bangalore/best-brews-fo...
# 51713  https://www.zomato.com/bangalore/vinod-bar-and...
# 51714  https://www.zomato.com/bangalore/plunge-sherat...
# 51715  https://www.zomato.com/bangalore/chime-sherato...
# 51716  https://www.zomato.com/bangalore/the-nest-the-...
#
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# ...

# %% [markdown]
# **Insight:**
# Loading the file from local system to jupyter notebook

# %%
# Print the shape i.e. the row size by column size of the dataset
df.shape
# Out:
# (51717, 17)

# %% [markdown]
# **Insight**
# Here we print row and column size of the dataset

# %% [markdown]
# # *Dataset View*

# %%
# Prints the first 5 rows of the dataset
df.head()
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
#
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_table   rate  votes                             phone  \
# 0          Yes        Yes  4.1/5    775    080 42297555\r\n+91 9743772233
# ...

# %% [markdown]
# **Insight**
# Here we print first five rows of the dataset.

# %%
# Prints the last 5 rows of the dataset
df.tail()
# Out:
#                                                      url  \
# 51712  https://www.zomato.com/bangalore/best-brews-fo...
# 51713  https://www.zomato.com/bangalore/vinod-bar-and...
# 51714  https://www.zomato.com/bangalore/plunge-sherat...
# 51715  https://www.zomato.com/bangalore/chime-sherato...
# 51716  https://www.zomato.com/bangalore/the-nest-the-...
#
#                                                  address  \
# 51712  Four Points by Sheraton Bengaluru, 43/3, White...
# 51713  Number 10, Garudachar Palya, Mahadevapura, Whi...
# 51714  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 51715  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 51716  ITPL Main Road, KIADB Export Promotion Industr...
#
#                                                     name online_order  \
# 51712  Best Brews - Four Points by Sheraton Bengaluru...           No
# 51713                           Vinod Bar And Restaurant           No
# ...

# %% [markdown]
# **Insight**
# Here we print last five rows of the dataset

# %%
# To print the column names present in the dataset.
df.columns
# Out:
# Index(['url', 'address', 'name', 'online_order', 'book_table', 'rate', 'votes',
#        'phone', 'location', 'rest_type', 'dish_liked', 'cuisines',
#        'approx_cost(for two people)', 'reviews_list', 'menu_item',
#        'listed_in(type)', 'listed_in(city)'],
#       dtype='object')

# %% [markdown]
# **Insight**
# Print the column name present in the dataset

# %% [markdown]
# # *Understanding Variable*

# %%
# **- url:** URL of the restaurant's Zomato page
# **- address:** Address of the restaurant
# - name: Name of the restaurant
# - online_order: Whether the restaurant accepts online orders (Yes/No)
# - book_table: Whether the restaurant allows table bookings (Yes/No)
# - rate: Restaurant rating out of 5
# - votes: Number of votes the restaurant has received
# - phone: Contact number(s) of the restaurant
# - location: The location of the restaurant
# - rest_type: Type of restaurant (Casual Dining, Cafe, etc.)
# - dish_liked: Most liked dishes in the restaurant
# - cuisines: Cuisines offered by the restaurant
# - approx_cost(for two): Approximate cost for two people (in ₹)
# - reviews_list: List of reviews (if available)
# - menu_item: Menu items listed
# - listed_in(type): Whether the restaurant is listed for Buffet or Cafes
# - listed_in(city): City where the restaurant is listed

# %% [markdown]
# # *Dataset Information*

# %%
# Gives the a concise summary of a DataFrame.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51717 entries, 0 to 51716
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   url                          51717 non-null  object
#  1   address                      51717 non-null  object
#  2   name                         51717 non-null  object
#  3   online_order                 51717 non-null  object
#  4   book_table                   51717 non-null  object
#  5   rate                         43942 non-null  object
#  6   votes                        51717 non-null  int64
#  7   phone                        50509 non-null  object
#  8   location                     51696 non-null  object
#  9   rest_type                    51490 non-null  object
#  10  dish_liked                   23639 non-null  object
#  11  cuisines                     51672 non-null  object
#  12  approx_cost(for two people)  51371 non-null  object
# ...

# %% [markdown]
# **Insight**
# We use info() to get concise summary of our dataset i.e column, non null , count , memory usage and datatype.

# %% [markdown]
# # *Missing Values/Null Values*

# %%
# It is used to identify and count missing values (NaNs) in a DataFrame
df.isnull().sum()
# Out:
# url                                0
# address                            0
# name                               0
# online_order                       0
# book_table                         0
# rate                            7775
# votes                              0
# phone                           1208
# location                          21
# rest_type                        227
# dish_liked                     28078
# cuisines                          45
# approx_cost(for two people)      346
# reviews_list                       0
# menu_item                          0
# listed_in(type)                    0
# listed_in(city)                    0
# dtype: int64

# %% [markdown]
# **Insight**
# Here we used isnull().sum() to identify and count missing values (NaNs) in a DataFrame

# %%
# Dropping columns that are not necessary for the analysis to reduce data complexity and focus on relevant features.
df = df.drop(['url', 'address', 'phone', 'menu_item', 'dish_liked', 'reviews_list'], axis=1)

# Displaying the first few rows of the cleaned DataFrame to verify the remaining columns.
df.head()
# Out:
#                     name online_order book_table   rate  votes      location  \
# 0                  Jalsa          Yes        Yes  4.1/5    775  Banashankari
# 1         Spice Elephant          Yes         No  4.1/5    787  Banashankari
# 2        San Churro Cafe          Yes         No  3.8/5    918  Banashankari
# 3  Addhuri Udupi Bhojana           No         No  3.7/5     88  Banashankari
# 4          Grand Village           No         No  3.8/5    166  Basavanagudi
#
#              rest_type                        cuisines  \
# 0        Casual Dining  North Indian, Mughlai, Chinese
# 1        Casual Dining     Chinese, North Indian, Thai
# 2  Cafe, Casual Dining          Cafe, Mexican, Italian
# 3          Quick Bites      South Indian, North Indian
# 4        Casual Dining        North Indian, Rajasthani
#
#   approx_cost(for two people) listed_in(type) listed_in(city)
# 0                         800          Buffet    Banashankari
# ...

# %% [markdown]
# **Insight :**
#
# By removing non-essential columns, the dataset is streamlined for analysis, focusing on key features that contribute to understanding restaurant ratings and cuisines.

# %%
# The df.info() method outputs a summary of the DataFrame, showing non-null counts, data types, and memory usage.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51717 entries, 0 to 51716
# Data columns (total 11 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   name                         51717 non-null  object
#  1   online_order                 51717 non-null  object
#  2   book_table                   51717 non-null  object
#  3   rate                         43942 non-null  object
#  4   votes                        51717 non-null  int64
#  5   location                     51696 non-null  object
#  6   rest_type                    51490 non-null  object
#  7   cuisines                     51672 non-null  object
#  8   approx_cost(for two people)  51371 non-null  object
#  9   listed_in(type)              51717 non-null  object
#  10  listed_in(city)              51717 non-null  object
# dtypes: int64(1), object(10)
# memory usage: 4.3+ MB

# %% [markdown]
# **Insight**
#  It indicates the presence of missing values and the overall structure of the dataset, guiding further data cleaning steps.

# %% [markdown]
# # **Dropping Duplicates**

# %%
# The drop_duplicates() method removes any duplicate rows from the DataFrame, ensuring each entry is unique.
df.drop_duplicates(inplace = True)
df.shape
# Out:
# (51609, 11)

# %% [markdown]
# **Insight :**
#
#  After executing this, the DataFrame's shape reflects the number of unique records, which is crucial for accurate analysis.

# %% [markdown]
# # **Cleaning Rate Column**

# %%
# The unique() method returns all distinct values present in the 'rate' column, helping to understand the variety of ratings in the dataset.
df['rate'].unique()
# Out:
# array(['4.1/5', '3.8/5', '3.7/5', '3.6/5', '4.6/5', '4.0/5', '4.2/5',
#        '3.9/5', '3.1/5', '3.0/5', '3.2/5', '3.3/5', '2.8/5', '4.4/5',
#        '4.3/5', 'NEW', '2.9/5', '3.5/5', nan, '2.6/5', '3.8 /5', '3.4/5',
#        '4.5/5', '2.5/5', '2.7/5', '4.7/5', '2.4/5', '2.2/5', '2.3/5',
#        '3.4 /5', '-', '3.6 /5', '4.8/5', '3.9 /5', '4.2 /5', '4.0 /5',
#        '4.1 /5', '3.7 /5', '3.1 /5', '2.9 /5', '3.3 /5', '2.8 /5',
#        '3.5 /5', '2.7 /5', '2.5 /5', '3.2 /5', '2.6 /5', '4.5 /5',
#        '4.3 /5', '4.4 /5', '4.9/5', '2.1/5', '2.0/5', '1.8/5', '4.6 /5',
#        '4.9 /5', '3.0 /5', '4.8 /5', '2.3 /5', '4.7 /5', '2.4 /5',
#        '2.1 /5', '2.2 /5', '2.0 /5', '1.8 /5'], dtype=object)

# %% [markdown]
# **Insight**
# This allows for a better assessment of how ratings are distributed and can inform any further analysis or visualizations.

# %% [markdown]
# # **Removing "NEW" , "-" and "/5" from Rate Column**

# %%
# Define a function to handle and clean the 'rate' values from the dataset.
def handlerate(value):
    # Check if the value is 'NEW' or '-', which indicates a non-numeric rate, and return NaN for those cases.
    if(value=='NEW' or value=='-'):
        return np.nan
    else:
        # Split the string by '/' to handle cases with multiple ratings and select the first part.
        value = str(value).split('/')
        value = value[0]  # Get the first rating value from the split.
        return float(value)  # Convert the extracted rating to a float for numerical analysis.
    
# Apply the handlerate function to the 'rate' column to clean the data.
df['rate'] = df['rate'].apply(handlerate)

# Display the first five entries of the cleaned 'rate' column.
df['rate'].head()
# Out:
# 0    4.1
# 1    4.1
# 2    3.8
# 3    3.7
# 4    3.8
# Name: rate, dtype: float64

# %% [markdown]
# **Insight :**
#
# This function effectively cleans the 'rate' column by converting invalid entries to NaN and extracting the first numeric rating for further analysis.

# %% [markdown]
# # **Filling Null Values in Rate Column with Mean**

# %%
# Fill any NaN values in the 'rate' column with the mean rating to maintain data continuity.
df['rate'].fillna(df['rate'].mean(), inplace = True)

# Check the number of missing values in the 'rate' column after filling NaNs.
df['rate'].isnull().sum()

# Display the DataFrame's information, including the data types and the number of non-null entries for each column.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 51609 entries, 0 to 51716
# Data columns (total 11 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   name                         51609 non-null  object
#  1   online_order                 51609 non-null  object
#  2   book_table                   51609 non-null  object
#  3   rate                         51609 non-null  float64
#  4   votes                        51609 non-null  int64
#  5   location                     51588 non-null  object
#  6   rest_type                    51382 non-null  object
#  7   cuisines                     51564 non-null  object
#  8   approx_cost(for two people)  51265 non-null  object
#  9   listed_in(type)              51609 non-null  object
#  10  listed_in(city)              51609 non-null  object
# dtypes: float64(1), int64(1), object(9)
# memory usage: 4.7+ MB

# %% [markdown]
# **Insight :**
#
# The process ensures that all missing values in the 'rate' column are addressed, allowing for a complete dataset for further analysis.

# %% [markdown]
# # **Dropping Null Values**

# %%
# Remove any rows with missing values from the DataFrame to ensure data integrity for analysis.
df.dropna(inplace = True)

# Display the first few rows of the cleaned DataFrame after dropping rows with missing values.
df.head()
# Out:
#                     name online_order book_table  rate  votes      location  \
# 0                  Jalsa          Yes        Yes   4.1    775  Banashankari
# 1         Spice Elephant          Yes         No   4.1    787  Banashankari
# 2        San Churro Cafe          Yes         No   3.8    918  Banashankari
# 3  Addhuri Udupi Bhojana           No         No   3.7     88  Banashankari
# 4          Grand Village           No         No   3.8    166  Basavanagudi
#
#              rest_type                        cuisines  \
# 0        Casual Dining  North Indian, Mughlai, Chinese
# 1        Casual Dining     Chinese, North Indian, Thai
# 2  Cafe, Casual Dining          Cafe, Mexican, Italian
# 3          Quick Bites      South Indian, North Indian
# 4        Casual Dining        North Indian, Rajasthani
#
#   approx_cost(for two people) listed_in(type) listed_in(city)
# 0                         800          Buffet    Banashankari
# ...

# %% [markdown]
# **Insight :**
#
# The removal of rows with missing values enhances the quality of the dataset, ensuring that subsequent analyses are performed on complete data.

# %%
# Rename the column 'approx_cost(for two people)' to 'Cost2plates' for better readability and clarity.
df.rename(columns = {'approx_cost(for two people)':'Cost2plates', 'listed_in(type)':'Type'}, inplace = True)

# Display the first few rows of the DataFrame to confirm that the columns have been renamed successfully.
df.head()
# Out:
#                     name online_order book_table  rate  votes      location  \
# 0                  Jalsa          Yes        Yes   4.1    775  Banashankari
# 1         Spice Elephant          Yes         No   4.1    787  Banashankari
# 2        San Churro Cafe          Yes         No   3.8    918  Banashankari
# 3  Addhuri Udupi Bhojana           No         No   3.7     88  Banashankari
# 4          Grand Village           No         No   3.8    166  Basavanagudi
#
#              rest_type                        cuisines Cost2plates    Type  \
# 0        Casual Dining  North Indian, Mughlai, Chinese         800  Buffet
# 1        Casual Dining     Chinese, North Indian, Thai         800  Buffet
# 2  Cafe, Casual Dining          Cafe, Mexican, Italian         800  Buffet
# 3          Quick Bites      South Indian, North Indian         300  Buffet
# 4        Casual Dining        North Indian, Rajasthani         600  Buffet
#
#   listed_in(city)
# 0    Banashankari
# 1    Banashankari
# ...

# %% [markdown]
# **Insight :**
#
# Renaming columns enhances the interpretability of the dataset, making it easier to understand the data's context and facilitating analysis.

# %%
# Retrieve the unique values from the 'location' column to understand the different locations represented in the dataset.
df['location'].unique()
# Out:
# array(['Banashankari', 'Basavanagudi', 'Mysore Road', 'Jayanagar',
#        'Kumaraswamy Layout', 'Rajarajeshwari Nagar', 'Vijay Nagar',
#        'Uttarahalli', 'JP Nagar', 'South Bangalore', 'City Market',
#        'Nagarbhavi', 'Bannerghatta Road', 'BTM', 'Kanakapura Road',
#        'Bommanahalli', 'CV Raman Nagar', 'Electronic City', 'HSR',
#        'Marathahalli', 'Wilson Garden', 'Shanti Nagar',
#        'Koramangala 5th Block', 'Koramangala 8th Block', 'Richmond Road',
#        'Koramangala 7th Block', 'Jalahalli', 'Koramangala 4th Block',
#        'Bellandur', 'Sarjapur Road', 'Whitefield', 'East Bangalore',
#        'Old Airport Road', 'Indiranagar', 'Koramangala 1st Block',
#        'Frazer Town', 'RT Nagar', 'MG Road', 'Brigade Road',
#        'Lavelle Road', 'Church Street', 'Ulsoor', 'Residency Road',
#        'Shivajinagar', 'Infantry Road', 'St. Marks Road',
#        'Cunningham Road', 'Race Course Road', 'Commercial Street',
# ...

# %% [markdown]
# **Insight :**
#
# Analyzing the unique locations helps identify the geographical diversity of the dataset, which can be crucial for location-based insights and trends.

# %%
# Count the number of unique locations in the 'location' column
num_unique_locations = df['location'].nunique()

# Display the number of unique locations
print(f"Number of unique locations: {num_unique_locations}")
# Out:
# Number of unique locations: 93

# %% [markdown]
# **Insight :**
# It displays the number of unique locations

# %%
# Retrieve the unique values from the 'listed_in(city)' column to understand the various cities represented in the dataset.
df['listed_in(city)'].unique()
# Out:
# array(['Banashankari', 'Bannerghatta Road', 'Basavanagudi', 'Bellandur',
#        'Brigade Road', 'Brookefield', 'BTM', 'Church Street',
#        'Electronic City', 'Frazer Town', 'HSR', 'Indiranagar',
#        'Jayanagar', 'JP Nagar', 'Kalyan Nagar', 'Kammanahalli',
#        'Koramangala 4th Block', 'Koramangala 5th Block',
#        'Koramangala 6th Block', 'Koramangala 7th Block', 'Lavelle Road',
#        'Malleshwaram', 'Marathahalli', 'MG Road', 'New BEL Road',
#        'Old Airport Road', 'Rajajinagar', 'Residency Road',
#        'Sarjapur Road', 'Whitefield'], dtype=object)

# %% [markdown]
# **Insight :**
#
# Identifying unique cities allows for targeted analysis of restaurant trends and preferences across different urban areas.

# %% [markdown]
# # **Listed in(city) and location, both are there, lets keep only one.**

# %%
# Drop the 'listed_in(city)' column from the DataFrame to streamline the dataset by removing unnecessary information.
df = df.drop(['listed_in(city)'], axis = 1)

# %% [markdown]
# **Insight :**
#
# Removing this column may help focus on more relevant features, especially if the city data is not essential for analysis.

# %%
# Display the unique values in the 'Cost2plates' column to understand the variety of cost estimates for two people.
df['Cost2plates'].unique()
# Out:
# array(['800', '300', '600', '700', '550', '500', '450', '650', '400',
#        '900', '200', '750', '150', '850', '100', '1,200', '350', '250',
#        '950', '1,000', '1,500', '1,300', '199', '80', '1,100', '160',
#        '1,600', '230', '130', '50', '190', '1,700', '1,400', '180',
#        '1,350', '2,200', '2,000', '1,800', '1,900', '330', '2,500',
#        '2,100', '3,000', '2,800', '3,400', '40', '1,250', '3,500',
#        '4,000', '2,400', '2,600', '120', '1,450', '469', '70', '3,200',
#        '60', '560', '240', '360', '6,000', '1,050', '2,300', '4,100',
#        '5,000', '3,700', '1,650', '2,700', '4,500', '140'], dtype=object)

# %% [markdown]
# **Insight :**
#
# Analyzing unique cost values can help identify pricing trends and assist in categorizing restaurants based on affordability.

# %% [markdown]
# # **Removing , from Cost2Plates Column**

# %%
def handlecomma(value):
    value = str(value)
    if ',' in value:
        value = value.replace(',', '')
        return float(value)
    else:
        return float(value)
    
df['Cost2plates'] = df['Cost2plates'].apply(handlecomma)
df['Cost2plates'].unique()
# Out:
# array([ 800.,  300.,  600.,  700.,  550.,  500.,  450.,  650.,  400.,
#         900.,  200.,  750.,  150.,  850.,  100., 1200.,  350.,  250.,
#         950., 1000., 1500., 1300.,  199.,   80., 1100.,  160., 1600.,
#         230.,  130.,   50.,  190., 1700., 1400.,  180., 1350., 2200.,
#        2000., 1800., 1900.,  330., 2500., 2100., 3000., 2800., 3400.,
#          40., 1250., 3500., 4000., 2400., 2600.,  120., 1450.,  469.,
#          70., 3200.,   60.,  560.,  240.,  360., 6000., 1050., 2300.,
#        4100., 5000., 3700., 1650., 2700., 4500.,  140.])

# %% [markdown]
# **Insight :**
#
# Cleaning the 'Cost2plates' column ensures consistency in data format, which is crucial for accurate cost analysis and categorization. It also prepares the data for further operations.

# %%
df.head()
# Out:
#                     name online_order book_table  rate  votes      location  \
# 0                  Jalsa          Yes        Yes   4.1    775  Banashankari
# 1         Spice Elephant          Yes         No   4.1    787  Banashankari
# 2        San Churro Cafe          Yes         No   3.8    918  Banashankari
# 3  Addhuri Udupi Bhojana           No         No   3.7     88  Banashankari
# 4          Grand Village           No         No   3.8    166  Basavanagudi
#
#              rest_type                        cuisines  Cost2plates    Type
# 0        Casual Dining  North Indian, Mughlai, Chinese        800.0  Buffet
# 1        Casual Dining     Chinese, North Indian, Thai        800.0  Buffet
# 2  Cafe, Casual Dining          Cafe, Mexican, Italian        800.0  Buffet
# 3          Quick Bites      South Indian, North Indian        300.0  Buffet
# 4        Casual Dining        North Indian, Rajasthani        600.0  Buffet

# %% [markdown]
# **Insight :**
#
# By reviewing the output of df.head(), you can assess whether the data transformations were successful and if the DataFrame is now ready for further analysis.

# %% [markdown]
# # **Cleaning Rest Type Column**

# %%
# Count the occurrences of each unique restaurant type in the 'rest_type' column.
rest_types = df['rest_type'].value_counts(ascending=False)

# Display the counts of restaurant types.
rest_types
# Out:
# rest_type
# Quick Bites                   19010
# Casual Dining                 10253
# Cafe                           3682
# Delivery                       2574
# Dessert Parlor                 2242
#                               ...
# Dessert Parlor, Kiosk             2
# Food Court, Beverage Shop         2
# Dessert Parlor, Food Court        2
# Quick Bites, Kiosk                1
# Sweet Shop, Dessert Parlor        1
# Name: count, Length: 93, dtype: int64

# %% [markdown]
# **Insight :**
#
# The rest_types output reveals the distribution of restaurant types, highlighting the most popular categories within the dataset.

# %%
# Filter the restaurant types to include only those with fewer than 1000 occurrences
rest_types_lessthan1000 = rest_types[rest_types < 1000]  
# Display the restaurant types that are less common in the dataset
rest_types_lessthan1000
# Out:
# rest_type
# Beverage Shop                 863
# Bar                           686
# Food Court                    616
# Sweet Shop                    468
# Bar, Casual Dining            411
#                              ...
# Dessert Parlor, Kiosk           2
# Food Court, Beverage Shop       2
# Dessert Parlor, Food Court      2
# Quick Bites, Kiosk              1
# Sweet Shop, Dessert Parlor      1
# Name: count, Length: 85, dtype: int64

# %% [markdown]
# **Insight :**
#
# The rest_types_lessthan1000 variable shows the less prevalent restaurant types, indicating that the majority of the dataset is dominated by a few popular categories.

# %% [markdown]
# # **Making Rest Types less than 1000 in frequency as others**

# %%
# Define a function to categorize restaurant types with fewer than 1000 occurrences as 'others'
def handle_rest_type(value):
    if(value in rest_types_lessthan1000):
        return 'others'  # Assign 'others' if the restaurant type is less common
    else:
        return value  # Keep the original type for more common restaurant types

# Apply the function to the 'rest_type' column to classify types
df['rest_type'] = df['rest_type'].apply(handle_rest_type)  
# Count the occurrences of each restaurant type after categorization
df['rest_type'].value_counts()
# Out:
# rest_type
# Quick Bites           19010
# Casual Dining         10253
# others                 9003
# Cafe                   3682
# Delivery               2574
# Dessert Parlor         2242
# Takeaway, Delivery     2008
# Bakery                 1140
# Casual Dining, Bar     1130
# Name: count, dtype: int64

# %% [markdown]
# **Insight :**
#
# The transformation groups less common restaurant types into an "others" category, simplifying the analysis by focusing on the predominant types.

# %% [markdown]
# # **Cleaning Location Column**

# %%
# Count the occurrences of each location in the dataset
location = df['location'].value_counts(ascending=False)  

# Filter locations that occur less than 300 times
location_lessthan300 = location[location < 300]  

# Define a function to categorize locations with fewer than 300 occurrences as 'others'
def handle_location(value):
    if(value in location_lessthan300):  
        return 'others'  # Assign 'others' if the location is less common
    else:
        return value  # Keep the original location for more common entries

# Apply the function to the 'location' column to classify locations
df['location'] = df['location'].apply(handle_location)  
# Count the occurrences of each location after categorization
df['location'].value_counts()
# Out:
# location
# BTM                      5056
# others                   4954
# HSR                      2494
# Koramangala 5th Block    2479
# JP Nagar                 2218
# Whitefield               2105
# Indiranagar              2026
# Jayanagar                1916
# Marathahalli             1805
# Bannerghatta Road        1609
# Bellandur                1268
# Electronic City          1246
# Koramangala 1st Block    1236
# Brigade Road             1210
# Koramangala 7th Block    1174
# Koramangala 6th Block    1127
# Sarjapur Road            1047
# Koramangala 4th Block    1017
# Ulsoor                   1011
# Banashankari              902
# MG Road                   893
# Kalyan Nagar              841
# Richmond Road             803
# Malleshwaram              721
# Frazer Town               714
# Basavanagudi              684
# Residency Road            671
# Brookefield               656
# New BEL Road              644
# Banaswadi                 640
# ...

# %% [markdown]
# **Insight:**
#
# This categorization consolidates less frequent locations into an "others" category, enabling a clearer focus on the most significant locations in the dataset.

# %% [markdown]
# # **Cleaning Cuisines Column**

# %%
# Count the occurrences of each cuisine type in the dataset
cuisines = df['cuisines'].value_counts(ascending=False)  

# Filter cuisines that occur less than 100 times
cuisines_lessthan100 = cuisines[cuisines < 100]  

# Define a function to categorize cuisines with fewer than 100 occurrences as 'others'
def handle_cuisines(value):
    if(value in cuisines_lessthan100):  
        return 'others'  # Assign 'others' if the cuisine is less common
    else:
        return value  # Keep the original cuisine for more common entries

# Apply the function to the 'cuisines' column to classify cuisines
df['cuisines'] = df['cuisines'].apply(handle_cuisines)  
# Count the occurrences of each cuisine after categorization
df['cuisines'].value_counts()
# Out:
# cuisines
# others                                 26159
# North Indian                            2852
# North Indian, Chinese                   2351
# South Indian                            1820
# Biryani                                  903
#                                        ...
# South Indian, Chinese, North Indian      105
# North Indian, Mughlai, Chinese           104
# South Indian, Fast Food                  104
# Italian, Pizza                           102
# North Indian, Chinese, Seafood           102
# Name: count, Length: 70, dtype: int64

# %% [markdown]
# **Insight :**
# This categorization consolidates less common cuisines into an "others" category, simplifying the analysis and highlighting the more popular cuisine types in the dataset.

# %%
# Display the first five rows of the DataFrame after data cleaning and transformation
df.head()
# Out:
#                     name online_order book_table  rate  votes      location  \
# 0                  Jalsa          Yes        Yes   4.1    775  Banashankari
# 1         Spice Elephant          Yes         No   4.1    787  Banashankari
# 2        San Churro Cafe          Yes         No   3.8    918  Banashankari
# 3  Addhuri Udupi Bhojana           No         No   3.7     88  Banashankari
# 4          Grand Village           No         No   3.8    166  Basavanagudi
#
#        rest_type                        cuisines  Cost2plates    Type
# 0  Casual Dining  North Indian, Mughlai, Chinese        800.0  Buffet
# 1  Casual Dining                          others        800.0  Buffet
# 2         others                          others        800.0  Buffet
# 3    Quick Bites      South Indian, North Indian        300.0  Buffet
# 4  Casual Dining                          others        600.0  Buffet

# %% [markdown]
# **Insight :**
#
# The DataFrame now shows consolidated categories for location, cuisines, and rest_type, improving clarity and manageability for further analysis.

# %% [markdown]
# # **Data Visualization**

# %% [markdown]
# # **Chart 1(Visualizing Online Order)**

# %%
# Group the data by 'online_order' and count the occurrences
online_order_counts = df['online_order'].value_counts()

# Set the figure size to 6x6
plt.figure(figsize=(6, 6))

# Create a color palette that is vibrant but not too bright
colors = sns.color_palette('Set2', len(online_order_counts))

# Plot the pie chart with the new color palette
plt.pie(online_order_counts, labels=online_order_counts.index, autopct='%1.1f%%', colors=colors, startangle=90)

# Set the title for the pie chart
plt.title('Online Order Distribution')

# Display the pie chart
plt.show()

# %% [markdown]
# **Insight :**
#
# The chart shows that 59.2% of customers prefer online orders, indicating a strong demand for online services. However, 40.8% still choose offline options, emphasizing the need for maintaining both channels.

# %% [markdown]
# # **Chart 2(Visualizing Book Table)**

# %%
# Group the data by 'book_table' and count the occurrences
book_table_counts = df['book_table'].value_counts()

# Set the figure size to 6x6 for a square-shaped display
plt.figure(figsize=(6, 6))

# Use a moderately dark color palette
colors = sns.color_palette('husl', len(book_table_counts))

# Plot the pie chart with the new color palette
plt.pie(book_table_counts, labels=book_table_counts.index, autopct='%1.1f%%', colors=colors, startangle=90)

# Set the title for the pie chart
plt.title('Book Table Distribution')

# Display the pie chart
plt.show()

# %% [markdown]
# **Insight :**
#
# The chart indicates that most customers do not prefer booking a table, with over 87.4% "No" responses compared to a much smaller number of "Yes" responses. This suggests table booking is not a widely used feature.

# %% [markdown]
# # **Chart 3(Visualizing Online Order Facility, Location Wise)**

# %%
# Group the dataframe by 'location' and 'online_order', then count the occurrences of 'name'
df1 = df.groupby(['location','online_order'])['name'].count()

# Save the grouped data to a CSV file named 'location_online.csv'
df1.to_csv('location_online.csv')

# Read the CSV file back into a dataframe
df1 = pd.read_csv('location_online.csv')

# Create a pivot table with 'location' as the index and 'online_order' as the columns, 
# filling any missing values with 0 and summing the counts
df1 = pd.pivot_table(df1, values=None, index=['location'], columns=['online_order'], fill_value=0, aggfunc=np.sum)

# Display the resulting pivot table
df1
# Out:
# C:\Users\akans\AppData\Local\Temp\ipykernel_3620\3362424747.py:12: FutureWarning: The provided callable <function sum at 0x000001E17B7DA170> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   df1 = pd.pivot_table(df1, values=None, index=['location'], columns=['online_order'], fill_value=0, aggfunc=np.sum)
#                        name
# online_order             No   Yes
# location
# BTM                    1763  3293
# Banashankari            397   505
# Banaswadi               302   338
# Bannerghatta Road       685   924
# Basavanagudi            243   441
# Bellandur               517   751
# Brigade Road            552   658
# Brookefield             239   417
# Church Street           226   340
# Commercial Street       228   142
# Cunningham Road         168   322
# Domlur                  247   235
# Ejipura                 214   219
# ...

# %% [markdown]
# **Insight :**
#
#  **BTM** has 1763 establishments without online ordering and 3293 that offer it, indicating higher range of restuarants that provide online order.

# %%
# Group the dataframe by 'location' and 'online_order', then count the occurrences of 'name'
df1 = df.groupby(['location', 'online_order'])['name'].count()

# Save the grouped data to a CSV file named 'location_online.csv'
df1.to_csv('location_online.csv')

# Read the CSV file back into a dataframe
df1 = pd.read_csv('location_online.csv')

# Create a pivot table with 'location' as the index and 'online_order' as the columns, filling missing values with 0
df1 = pd.pivot_table(df1, values='name', index=['location'], columns=['online_order'], fill_value=0, aggfunc=np.sum)

# Sort by the total count across 'online_order' types and select the top 10 locations
df1['Total'] = df1.sum(axis=1)
df1_top10 = df1.sort_values(by='Total', ascending=False).head(10).drop(columns='Total')

# Create a bar plot for the top 10 locations
df1_top10.plot(kind='bar', figsize=(15, 8))

# Add the y-axis label
plt.ylabel('Count')

# Rotate the x-axis labels by 90 degrees for better readability
plt.xticks(rotation=45)

# Set the title for the bar plot
plt.title('Top 10 Locations with Online Order Facility')

# Display the plot
plt.show()
# Out:
# C:\Users\akans\AppData\Local\Temp\ipykernel_3620\2422060804.py:11: FutureWarning: The provided callable <function sum at 0x000001E17B7DA170> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   df1 = pd.pivot_table(df1, values='name', index=['location'], columns=['online_order'], fill_value=0, aggfunc=np.sum)

# %% [markdown]
# **Insight :**
#
# The bar chart shows the Top 10 restaurants in each location that offer online ordering and those that don't. It's clear that online ordering is more prevalent in certain locations compared to others. So in this graph, BTM and HSR have a higher number of restaurants with online ordering, while Cunningham Road and Ejipura have relatively fewer.

# %% [markdown]
# # **Chart 4(Visualizing Book Table Facility, Location Wise)**

# %%
# Group the dataframe by 'location' and 'book_table', then count the occurrences of 'name'
df2 = df.groupby(['location', 'book_table'])['name'].count()

# Save the grouped data to a CSV file named 'location_booktable.csv'
df2.to_csv('location_booktable.csv')

# Read the CSV file back into a dataframe
df2 = pd.read_csv('location_booktable.csv')

# Create a pivot table with 'location' as the index and 'book_table' as the columns, 
# filling any missing values with 0 and summing the counts
df2 = pd.pivot_table(df2, values=None, index=['location'], columns=['book_table'], fill_value=0, aggfunc=np.sum)

# Display the resulting pivot table
df2
# Out:
# C:\Users\akans\AppData\Local\Temp\ipykernel_3620\1595233220.py:12: FutureWarning: The provided callable <function sum at 0x000001E17B7DA170> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   df2 = pd.pivot_table(df2, values=None, index=['location'], columns=['book_table'], fill_value=0, aggfunc=np.sum)
#                        name
# book_table               No  Yes
# location
# BTM                    4889  167
# Banashankari            839   63
# Banaswadi               632    8
# Bannerghatta Road      1510   99
# Basavanagudi            668   16
# Bellandur              1170   98
# Brigade Road           1034  176
# Brookefield             582   74
# Church Street           385  181
# Commercial Street       370    0
# Cunningham Road         315  175
# Domlur                  427   55
# Ejipura                 433    0
# Electronic City        1148   98
# ...

# %% [markdown]
# **Insight :**
#
# The pivot table shows the number of restaurants in each location that offer table bookings and those that don't. It's clear that table bookings are more prevalent in certain locations compared to others. For instance, Koramangala 5th Block and Indiranagar have a higher number of restaurants with table bookings, while BTM and HSR have relatively fewer.

# %%
# Group the dataframe by 'location' and 'book_table', then count the occurrences of 'name'
df2 = df.groupby(['location', 'book_table'])['name'].count()

# Save the grouped data to a CSV file named 'location_book_table.csv'
df2.to_csv('location_book_table.csv')

# Read the CSV file back into a dataframe
df2 = pd.read_csv('location_book_table.csv')

# Create a pivot table with 'location' as the index and 'book_table' as the columns, filling missing values with 0
df2 = pd.pivot_table(df2, values='name', index=['location'], columns=['book_table'], fill_value=0, aggfunc=np.sum)

# Sort by the total count across 'book_table' types and select the top 10 locations
df2['Total'] = df2.sum(axis=1)
df2_top10 = df2.sort_values(by='Total', ascending=False).head(10).drop(columns='Total')

# Create a bar plot for the top 10 locations
df2_top10.plot(kind='bar', figsize=(15, 8))

# Add the y-axis label
plt.ylabel('Count')

# Rotate the x-axis labels by 90 degrees for better readability
plt.xticks(rotation=45)

# Set the title for the bar plot
plt.title('Top 10 Locations with Booking Table Facility')

# Display the plot
plt.show()
# Out:
# C:\Users\akans\AppData\Local\Temp\ipykernel_3620\1733267608.py:11: FutureWarning: The provided callable <function sum at 0x000001E17B7DA170> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   df2 = pd.pivot_table(df2, values='name', index=['location'], columns=['book_table'], fill_value=0, aggfunc=np.sum)

# %% [markdown]
# **Insight :**
#
# The pivot table shows the number of top 10 restaurants in each location that offer table bookings and those that don't. It's clear that table bookings are more prevalent in certain locations compared to others. For instance, Koramangala 5th Block and Indiranagar have a higher number of restaurants with table bookings, while BTM and HSR have relatively fewer.

# %% [markdown]
# # **Chart 5(Visualizing Types of Restaurents vs Rate)**

# %%
# Set the figure size to 14x8 for a wider display
plt.figure(figsize=(14, 8))

# Create a boxplot to show the distribution of 'rate' based on 'Type'
# 'Type' is on the x-axis and 'rate' is on the y-axis, with 'inferno' color palette
sns.boxplot(x='Type', y='rate', data=df, palette='inferno')

# Change the background color of the axes
plt.gca().set_facecolor('white')  # Changing to white

# Set the title for the bar plot
plt.title('Types of Restaurents')

# Display the plot
plt.show()
# Out:
# C:\Users\akans\AppData\Local\Temp\ipykernel_3620\818777863.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Type', y='rate', data=df, palette='inferno')

# %% [markdown]
# **Insight :**
#
# The boxplot shows that restaurants offering buffet-style dining generally have higher median ratings compared to other types of restaurants. However, restaurants offering drinks and nightlife have the widest spread in their ratings, indicating a higher variability in customer satisfaction.

# %% [markdown]
# # **Chart 6(No. of Votes, Location Wise)**

# %%
# Select the 'location' and 'votes' columns from the original dataframe df
df4 = df[['location', 'votes']]

# Drop duplicate rows in df4 to ensure each location's votes are counted only once
df4.drop_duplicates(inplace=True)

# Group the dataframe by 'location' and sum the 'votes' for each location
df5 = df4.groupby(['location'])['votes'].sum()

# Convert the Series df5 to a DataFrame for easier manipulation and display
df5 = df5.to_frame()

# Sort df5 by the 'votes' column in descending order to identify the locations with the most votes
df5 = df5.sort_values('votes', ascending=False)

# Display the top rows of the sorted dataframe to view the results
df5.head()
# Out:
# C:\Users\akans\AppData\Local\Temp\ipykernel_3620\3938358652.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df4.drop_duplicates(inplace=True)
#                          votes
# location
# Koramangala 5th Block  1063061
# Indiranagar             648886
# Church Street           291543
# Koramangala 4th Block   282003
# JP Nagar                277901

# %% [markdown]
# **Insight :**
#
# The table shows the total number of votes received by each location. It's clear that Koramangala 5th Block is the most popular location based on the number of votes it has received, followed by Indiranagar and Church Street.

# %%
# Sort df5 by 'votes' in descending order and select the top 10 locations
df5_top10 = df5.sort_values(by='votes', ascending=False).head(10)

# Set the figure size to 15x8 for a wider display
plt.figure(figsize=(15, 8))

# Create a bar plot for the total votes by location
# Use df5_top10.index for x-axis (locations) and df5_top10['votes'] for y-axis (total votes)
sns.barplot(x=df5_top10.index, y=df5_top10['votes'])

# Rotate the x-axis labels by 90 degrees for better readability
plt.xticks(rotation=45)

# Set the title for the bar plot
plt.title('Top 10 Preferred Locations Based on Votes')

# Display the plot
plt.show()

# %% [markdown]
# **Insight :**
#
# The bar chart confirms that Koramangala 5th Block is the most popular location based on the number of votes, with a significant lead over other areas. Indiranagar and Church Street follow closely behind in terms of total votes received.

# %%
# Display the first few rows of the dataframe df to get an overview of its structure and contents
df.head()
# Out:
#                     name online_order book_table  rate  votes      location  \
# 0                  Jalsa          Yes        Yes   4.1    775  Banashankari
# 1         Spice Elephant          Yes         No   4.1    787  Banashankari
# 2        San Churro Cafe          Yes         No   3.8    918  Banashankari
# 3  Addhuri Udupi Bhojana           No         No   3.7     88  Banashankari
# 4          Grand Village           No         No   3.8    166  Basavanagudi
#
#        rest_type                        cuisines  Cost2plates    Type
# 0  Casual Dining  North Indian, Mughlai, Chinese        800.0  Buffet
# 1  Casual Dining                          others        800.0  Buffet
# 2         others                          others        800.0  Buffet
# 3    Quick Bites      South Indian, North Indian        300.0  Buffet
# 4  Casual Dining                          others        600.0  Buffet

# %% [markdown]
# **Insight :**
#
# The df.head() function gives a quick look at the dataset's structure and initial values, helping to identify variables and potential trends.

# %% [markdown]
# # **Chart 7(Visualizing Top Cuisines)**

# %%
# Select the 'cuisines' and 'votes' columns from the original dataframe df
df6 = df[['cuisines', 'votes']]

# Drop duplicate rows in df6
df6.drop_duplicates(inplace=True)

# Group the dataframe by 'cuisines' and sum the 'votes' for each cuisine type
df7 = df6.groupby(['cuisines'])['votes'].sum()

# Convert the Series df7 to a DataFrame for easier manipulation and display
df7 = df7.to_frame()

# Sort df7 by the 'votes' column in descending order to identify the most popular cuisines
df7 = df7.sort_values('votes', ascending=False)

# Display the top rows of the sorted dataframe
df7.head()
# Out:
# C:\Users\akans\AppData\Local\Temp\ipykernel_3620\1525912764.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df6.drop_duplicates(inplace=True)
#                          votes
# cuisines
# others                 3992844
# North Indian            242761
# South Indian             87286
# North Indian, Chinese    82290
# North Indian, Mughlai    65813

# %% [markdown]
# **Insight :**
#
# The table shows the total number of votes received by each cuisine type. It's clear that "North Indian" is the most popular cuisine category based on the number of votes it has received, followed South Indian.

# %%
# Remove the first row from the dataframe df7
df7 = df7.iloc[1:, :]

# Display the top rows of the modified dataframe
df7.head()
# Out:
#                         votes
# cuisines
# North Indian           242761
# South Indian            87286
# North Indian, Chinese   82290
# North Indian, Mughlai   65813
# Chinese                 40613

# %% [markdown]
# **Insight :**
#
# The table shows the total number of votes received by each cuisine type, excluding the "others" category. It's clear that North Indian cuisine is the most popular among the listed options, followed by South Indian and North Indian Chinese.

# %%
# Sort df7 by 'votes' in descending order and select the top 10 cuisines
df7_top10 = df7.sort_values(by='votes', ascending=False).head(10)

# Set the figure size to 15x8 for a wider display
plt.figure(figsize=(15, 8))

# Create a bar plot for the total votes by cuisine type
# Use df7_top10.index for x-axis (cuisines) and df7_top10['votes'] for y-axis (total votes)
sns.barplot(x=df7_top10.index, y=df7_top10['votes'])

# Rotate the x-axis labels by 90 degrees for better readability
plt.xticks(rotation=45)

# Set the title for the bar plot
plt.title('Top 10 Preferred Cuisines')

# Display the plot
plt.show()

# %% [markdown]
# **Insight :**
#
# The bar chart confirms that North Indian cuisine is the most popular among the listed options, followed by South Indian and North Indian, Chinese.

# %% [markdown]
# # **Conclusions:**
#
# **1.Online Ordering Popularity :** A majority of restaurants in the dataset offer online ordering, with around 30,000 providing this service compared to 22,000 that don’t. Online ordering has become a popular and essential feature in the current market.
#
# **2.Table Booking Trends :** Most customers do not prefer booking a table, as indicated by a significant number of "No" responses. However, certain areas such as Koramangala 5th Block and Indiranagar have more restaurants offering table bookings.
#
# **3.Impact of Online Orders on Ratings :** Restaurants that offer online ordering tend to have slightly higher median ratings compared to those that don’t, indicating that providing this feature could positively affect customer satisfaction.
#
# **4.Impact of Table Booking on Ratings :** Restaurants with table booking services generally have higher ratings, suggesting that offering a booking facility may enhance the customer experience and improve ratings.
#
# **5.Online Orders by Location :** Locations such as BTM and HSR have a large number of restaurants providing online orders, while areas like Cunningham Road and Ejipura have fewer. This shows that online ordering is more prevalent in certain areas.
#
# **6.Table Booking by Location :** Table bookings are more common in locations like Koramangala 5th Block and Indiranagar, while areas like BTM and HSR have fewer restaurants offering this service.
#
# **7.Restaurant Types and Ratings :** Buffet-style restaurants tend to have higher median ratings, while drinks and nightlife establishments show the most variability in ratings, which might indicate inconsistent service or customer experience.
#
# **8.Restaurant Types by Location :** Certain locations have a clear preference for different types of restaurants. For example, BTM has a high number of delivery and dine-out options, while Brigade Road and Koramangala have a larger share of drinks and nightlife establishments.

# %% [markdown]
# # **Recommendations:**
# **1.New Restaurant Openings :** Avoid opening restaurants in highly saturated areas like BTM and Koramangala 5th Block, where competition is stiff. Instead, consider under-served areas like Cunningham Road, Ejipura, or Banashankari, where the restaurant density is lower.
#
# **2.Focus on Online Ordering :** Given the popularity of online orders, ensure that any new restaurant offers online ordering as a standard service. This can not only boost customer satisfaction but also improve restaurant ratings.
#
# **3.Offer Table Booking in Specific Areas :** While table bookings are generally less popular, providing this service in high-end locations such as Koramangala or Indiranagar could be a competitive advantage, as customers in these areas seem to prefer the option.
#
# **4.Restaurant Type and Experience :** Consider focusing on buffet-style restaurants, especially if you aim to achieve higher customer ratings. Alternatively, if planning to open a drinks or nightlife venue, pay close attention to consistency in service quality to avoid variability in ratings.
#
# **5.Location-Specific Services :** Tailor your restaurant's offerings based on the location. For example, prioritize delivery options in areas like BTM and HSR, where it is highly popular. For nightlife or dine-out establishments, Brigade Road and Koramangala might be ideal.
#
# **6.Capitalize on Untapped Potential :** Locations with fewer online ordering or table booking services, such as Cunningham Road or Malleshwaram, represent untapped markets where introducing these features could capture unmet demand.
